# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
import kaggle
import matplotlib.pyplot as plt
import re
import numpy as np

# %% [markdown]
# # Data Collection

# %%
# !pip install kaggle

# %%
# # Download dataset
# !kaggle datasets download -d khusheekapoor/edx-courses-dataset-2021 --unzip

# %%
# Load the dataset into a pandas dataframe
kaggle_df = pd.read_csv('../raw_data/EdX.csv')
kaggle_df.head(10)
# Out:
#                                                 Name  \
# 0                                How to Learn Online
# 1  Programming for Everybody (Getting Started wit...
# 2            CS50's Introduction to Computer Science
# 3                                 The Analytics Edge
# 4  Marketing Analytics: Marketing Measurement Str...
# 5                 Introduction to Project Management
# 6                      Leading High-Performing Teams
# 7               The Foundations of Happiness at Work
# 8  Managing Study, Stress and Mental Health at Un...
# 9                      Six Sigma: Define and Measure
#
#                               University Difficulty Level  \
# 0                                    edX         Beginner
# 1             The University of Michigan         Beginner
# 2                     Harvard University         Beginner
# 3  Massachusetts Institute of Technology     Intermediate
# 4     University of California, Berkeley         Beginner
# 5                 University of Adelaide         Beginner
# 6           The University of Queensland     Intermediate
# 7     University of California, Berkeley         Beginner
# 8                      Curtin University         Beginner
# 9         Technische Universität München         Beginner
#
#                                                 Link  \
# 0     https://www.edx.org/course/how-to-learn-online
# 1  https://www.edx.org/course/programming-for-eve...
# 2  https://www.edx.org/course/cs50s-introduction-...
# 3      https://www.edx.org/course/the-analytics-edge
# 4  https://www.edx.org/course/marketing-analytics...
# 5  https://www.edx.org/course/introduction-to-pro...
# 6  https://www.edx.org/course/leading-high-perfor...
# 7  https://www.edx.org/course/the-foundations-of-...
# 8  https://www.edx.org/course/managing-study-stre...
# 9  https://www.edx.org/course/six-sigma-define-an...
#
#                                                About  \
# 0  Learn essential strategies for successful onli...
# 1  This course is a "no prerequisite" introductio...
# 2  An introduction to the intellectual enterprise...
# 3  Through inspiring examples and stories, discov...
# 4     This course is part of a MicroMasters® Program
# 5  Learn the principles of project management and...
# 6  Learn how to motivate, engage and empower peop...
# 7  Learn why happiness at work matters and how to...
# 8  Develop a clearer understanding of what mental...
# 9  An introduction to the Six Sigma methodology a...
#
#                                   Course Description
# 0  Designed for those who are new to elearning, t...
# 1  This course aims to teach everyone the basics ...
# 2  This is CS50x , Harvard University's introduct...
# 3  In the last decade, the amount of data availab...
# 4  Begin your journey in a new career in marketin...
# 5  Project management is an essential skill-set f...
# 6  This course will blend business theory and rea...
# 7  This course explains what happiness at work lo...
# 8  This short course is a German-Australian colla...
# 9  Understand the background and meaning of Six S...

# %% [markdown]
# # Data Cleaning

# %%
kaggle_df.columns
# Out:
# Index(['Name', 'University', 'Difficulty Level', 'Link', 'About',
#        'Course Description'],
#       dtype='object')

# %%
# Define keywords for the subjects we want
keywords = [
    "business", "finance", "entrepreneur", "marketing", "management",
    "math", "statistics", "calculus", "algebra", "probability",
    "computer science", "programming", "software", "coding", "data science",
    "machine learning", "AI", "artificial intelligence", "deep learning",
    "data analytics", "big data", "SQL", "Python", "R", "Excel",
    "design", "graphic design", "UX", "UI", "web design"
]

# Combine into regex pattern
pattern = re.compile(r"\b(" + "|".join(keywords) + r")\b", re.IGNORECASE)

# %%
# Apply filter: Keep rows where the course title or subject contains a keyword
filtered_df = kaggle_df[kaggle_df["Name"].astype(str).apply(lambda x: bool(pattern.search(x))) |
                 kaggle_df["Course Description"].astype(str).apply(lambda x: bool(pattern.search(x)))]

# Reset index after filtering
filtered_df.reset_index(drop=True, inplace=True)

filtered_df
# Out:
#                                                   Name  \
# 0                                  How to Learn Online
# 1    Programming for Everybody (Getting Started wit...
# 2              CS50's Introduction to Computer Science
# 3                                   The Analytics Edge
# 4    Marketing Analytics: Marketing Measurement Str...
# ..                                                 ...
# 460                                  The Power of Data
# 461  Drones and Autonomous Systems 2: Applications ...
# 462                  MathTrackX: Differential Calculus
# 463  Leaders in Citizen Security and Justice Manage...
# 464                      MathTrackX: Special Functions
#
#                                             University Difficulty Level  \
# 0                                                  edX         Beginner
# 1                           The University of Michigan         Beginner
# 2                                   Harvard University         Beginner
# 3                Massachusetts Institute of Technology     Intermediate
# 4                   University of California, Berkeley         Beginner
# ..                                                 ...              ...
# 460                                        Rolls-Royce         Beginner
# 461  University of Maryland Global Campus-Universit...     Intermediate
# 462                             University of Adelaide         Beginner
# 463                    Inter-American Development Bank     Intermediate
# 464                             University of Adelaide         Beginner
#
#                                                   Link  \
# 0       https://www.edx.org/course/how-to-learn-online
# 1    https://www.edx.org/course/programming-for-eve...
# 2    https://www.edx.org/course/cs50s-introduction-...
# 3        https://www.edx.org/course/the-analytics-edge
# 4    https://www.edx.org/course/marketing-analytics...
# ..                                                 ...
# 460       https://www.edx.org/course/the-power-of-data
# 461  https://www.edx.org/course/drones-and-autonomo...
# 462  https://www.edx.org/course/mathtrackx-differen...
# 463  https://www.edx.org/course/leaders-in-citizen-...
# 464  https://www.edx.org/course/mathtrackx-special-...
#
#                                                  About  \
# 0    Learn essential strategies for successful onli...
# 1    This course is a "no prerequisite" introductio...
# 2    An introduction to the intellectual enterprise...
# 3    Through inspiring examples and stories, discov...
# 4       This course is part of a MicroMasters® Program
# ..                                                 ...
# 460  'The power of data’ is an interactive introduc...
# 461  Learn the latest applications of unmanned aeri...
# 462  Discover concepts and techniques relating to d...
# 463  Learn about the latest in prevention, police a...
# 464  Understand trigonometric, exponential and loga...
#
#                                     Course Description
# 0    Designed for those who are new to elearning, t...
# 1    This course aims to teach everyone the basics ...
# 2    This is CS50x , Harvard University's introduct...
# 3    In the last decade, the amount of data availab...
# 4    Begin your journey in a new career in marketin...
# ..                                                 ...
# 460  Key course outcomes:High level overview of the...
# 461  If you want to be the technology specialist wh...
# 462  This course is part three of the MathTrackX XS...
# 463  The high rates of crime and violence are two o...
# 464  This course is part two of the MathTrackX XSer...
#
# [465 rows x 6 columns]

# %%
# Define category mapping with keywords
category_keywords = {
    "Business": ["business", "finance", "entrepreneur", "management", "accounting", "economics", "project management", "leadership", "strategy", "investment"],
    
    "Math": [
        "math", "mathematics", "statistics", "calculus", "algebra", "geometry", "probability", "trigonometry",
        "differential equations", "linear algebra", "discrete math", "topology", "combinatorics", "set theory",
        "real analysis", "complex analysis", "abstract algebra", "number theory", "graph theory", "logic",
        "game theory", "measure theory", "mathematical modeling", "stochastic processes", "numerical analysis",
        "multivariable calculus", "optimization", "vector calculus", "applied mathematics"
    ],
    
    "Computer Science": [
        "computer science", "programming", "software", "coding", "java", "python", "C++", "AI",
        "artificial intelligence", "web development", "cs50", "technology", "algorithms", "autonomous systems",
        "systems programming", "cybersecurity", "blockchain", "cloud computing", "machine learning",
        "deep learning", "neural networks", "operating systems", "computational thinking", "networking",
        "computer architecture", "embedded systems", "database systems", "theory of computation"
    ],
    
    "Data Analytics": [
        "data analytics", "big data", "SQL", "machine learning", "deep learning", "data science",
        "excel", "r programming", "data", "predictive modeling", "business intelligence", "data mining",
        "data visualization", "data engineering", "time series analysis", "ETL", "hadoop", "spark"
    ],
    
    "Design": [
        "design", "graphic design", "ux", "ui", "web design", "visual", "animation", "illustration",
        "motion graphics", "product design", "typography", "brand design", "3D modeling", "video editing",
        "industrial design", "color theory", "interaction design"
    ],
    
    "Marketing": [
        "marketing", "advertising", "seo", "branding", "digital marketing", "social media",
        "consumer behavior", "market research", "public relations", "copywriting", "growth hacking",
        "email marketing", "content marketing", "performance marketing"
    ]
}


# Create regex patterns for each category
category_patterns = {category: re.compile(r"\b(" + "|".join(keywords) + r")\b", re.IGNORECASE)
                     for category, keywords in category_keywords.items()}

# %%
# Function to assign category based on keyword frequency
def assign_category(title, description):
    text = f"{title} {description}".lower()  # Combine title and description for matching
    category_counts = {category: len(pattern.findall(text)) for category, pattern in category_patterns.items()}
    
    # Get the category with the highest match count
    best_category = max(category_counts, key=category_counts.get)

    # If no keywords are found, default to "Other"
    return best_category if category_counts[best_category] > 0 else "Other"

# Apply function to DataFrame
filtered_df["Category"] = filtered_df.apply(lambda row: assign_category(row["Name"], row["Course Description"]), axis=1)

filtered_df
# Out:
# /tmp/ipykernel_25397/2843159900.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df["Category"] = filtered_df.apply(lambda row: assign_category(row["Name"], row["Course Description"]), axis=1)
#                                                   Name  \
# 0                                  How to Learn Online
# 1    Programming for Everybody (Getting Started wit...
# 2              CS50's Introduction to Computer Science
# 3                                   The Analytics Edge
# 4    Marketing Analytics: Marketing Measurement Str...
# ..                                                 ...
# 460                                  The Power of Data
# 461  Drones and Autonomous Systems 2: Applications ...
# 462                  MathTrackX: Differential Calculus
# 463  Leaders in Citizen Security and Justice Manage...
# 464                      MathTrackX: Special Functions
#
#                                             University Difficulty Level  \
# 0                                                  edX         Beginner
# 1                           The University of Michigan         Beginner
# 2                                   Harvard University         Beginner
# 3                Massachusetts Institute of Technology     Intermediate
# 4                   University of California, Berkeley         Beginner
# ..                                                 ...              ...
# 460                                        Rolls-Royce         Beginner
# 461  University of Maryland Global Campus-Universit...     Intermediate
# 462                             University of Adelaide         Beginner
# 463                    Inter-American Development Bank     Intermediate
# 464                             University of Adelaide         Beginner
#
#                                                   Link  \
# 0       https://www.edx.org/course/how-to-learn-online
# 1    https://www.edx.org/course/programming-for-eve...
# 2    https://www.edx.org/course/cs50s-introduction-...
# 3        https://www.edx.org/course/the-analytics-edge
# 4    https://www.edx.org/course/marketing-analytics...
# ..                                                 ...
# 460       https://www.edx.org/course/the-power-of-data
# 461  https://www.edx.org/course/drones-and-autonomo...
# 462  https://www.edx.org/course/mathtrackx-differen...
# 463  https://www.edx.org/course/leaders-in-citizen-...
# 464  https://www.edx.org/course/mathtrackx-special-...
#
#                                                  About  \
# 0    Learn essential strategies for successful onli...
# 1    This course is a "no prerequisite" introductio...
# 2    An introduction to the intellectual enterprise...
# 3    Through inspiring examples and stories, discov...
# 4       This course is part of a MicroMasters® Program
# ..                                                 ...
# 460  'The power of data’ is an interactive introduc...
# 461  Learn the latest applications of unmanned aeri...
# 462  Discover concepts and techniques relating to d...
# 463  Learn about the latest in prevention, police a...
# 464  Understand trigonometric, exponential and loga...
#
#                                     Course Description          Category
# 0    Designed for those who are new to elearning, t...            Design
# 1    This course aims to teach everyone the basics ...  Computer Science
# 2    This is CS50x , Harvard University's introduct...  Computer Science
# 3    In the last decade, the amount of data availab...    Data Analytics
# 4    Begin your journey in a new career in marketin...         Marketing
# ..                                                 ...               ...
# 460  Key course outcomes:High level overview of the...    Data Analytics
# 461  If you want to be the technology specialist wh...          Business
# 462  This course is part three of the MathTrackX XS...              Math
# 463  The high rates of crime and violence are two o...          Business
# 464  This course is part two of the MathTrackX XSer...              Math
#
# [465 rows x 7 columns]

# %%
filtered_df.drop_duplicates(inplace=True)
filtered_df
# Out:
# /tmp/ipykernel_25397/2034316475.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df.drop_duplicates(inplace=True)
#                                                   Name  \
# 0                                  How to Learn Online
# 1    Programming for Everybody (Getting Started wit...
# 2              CS50's Introduction to Computer Science
# 3                                   The Analytics Edge
# 4    Marketing Analytics: Marketing Measurement Str...
# ..                                                 ...
# 460                                  The Power of Data
# 461  Drones and Autonomous Systems 2: Applications ...
# 462                  MathTrackX: Differential Calculus
# 463  Leaders in Citizen Security and Justice Manage...
# 464                      MathTrackX: Special Functions
#
#                                             University Difficulty Level  \
# 0                                                  edX         Beginner
# 1                           The University of Michigan         Beginner
# 2                                   Harvard University         Beginner
# 3                Massachusetts Institute of Technology     Intermediate
# 4                   University of California, Berkeley         Beginner
# ..                                                 ...              ...
# 460                                        Rolls-Royce         Beginner
# 461  University of Maryland Global Campus-Universit...     Intermediate
# 462                             University of Adelaide         Beginner
# 463                    Inter-American Development Bank     Intermediate
# 464                             University of Adelaide         Beginner
#
#                                                   Link  \
# 0       https://www.edx.org/course/how-to-learn-online
# 1    https://www.edx.org/course/programming-for-eve...
# 2    https://www.edx.org/course/cs50s-introduction-...
# 3        https://www.edx.org/course/the-analytics-edge
# 4    https://www.edx.org/course/marketing-analytics...
# ..                                                 ...
# 460       https://www.edx.org/course/the-power-of-data
# 461  https://www.edx.org/course/drones-and-autonomo...
# 462  https://www.edx.org/course/mathtrackx-differen...
# 463  https://www.edx.org/course/leaders-in-citizen-...
# 464  https://www.edx.org/course/mathtrackx-special-...
#
#                                                  About  \
# 0    Learn essential strategies for successful onli...
# 1    This course is a "no prerequisite" introductio...
# 2    An introduction to the intellectual enterprise...
# 3    Through inspiring examples and stories, discov...
# 4       This course is part of a MicroMasters® Program
# ..                                                 ...
# 460  'The power of data’ is an interactive introduc...
# 461  Learn the latest applications of unmanned aeri...
# 462  Discover concepts and techniques relating to d...
# 463  Learn about the latest in prevention, police a...
# 464  Understand trigonometric, exponential and loga...
#
#                                     Course Description          Category
# 0    Designed for those who are new to elearning, t...            Design
# 1    This course aims to teach everyone the basics ...  Computer Science
# 2    This is CS50x , Harvard University's introduct...  Computer Science
# 3    In the last decade, the amount of data availab...    Data Analytics
# 4    Begin your journey in a new career in marketin...         Marketing
# ..                                                 ...               ...
# 460  Key course outcomes:High level overview of the...    Data Analytics
# 461  If you want to be the technology specialist wh...          Business
# 462  This course is part three of the MathTrackX XS...              Math
# 463  The high rates of crime and violence are two o...          Business
# 464  This course is part two of the MathTrackX XSer...              Math
#
# [464 rows x 7 columns]

# %% [markdown]
# # Write to CSV

# %%
filtered_df.to_csv("../input_data/kaggle_filtered_courses.csv", index=False)
